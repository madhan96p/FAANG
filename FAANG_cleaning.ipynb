# %%
import pandas as pd
pd.set_option('display.max_columns', None)  # Shows all columns
pd.set_option('display.width', None)  # Shows full width
pd.set_option('display.max_colwidth', None) # Shows full content of the columns

# %%
df = pd.read_csv('FAANG.csv')

# %%
df.isnull().sum()
# Out:
# Company                                      0
# Ticker                                       0
# Date                                         0
# Open                                         0
# High                                         0
# Low                                          0
# Close                                        0
# Adj Close                                    0
# Volume                                       0
# Market Cap                                   0
# PE Ratio                                     0
# Beta                                      4982
# EPS                                          0
# Forward PE                                   0
# Revenue                                  23055
# Gross Profit                             23055
# Operating Income                         23055
# Net Income                                   0
# Debt to Equity                               0
# Return on Equity (ROE)                       0
# ...

# %%
pd.DataFrame(df[df.columns[df.isnull().sum() != 0]].isnull().sum())
# Out:
#                                            0
# Beta                                    4982
# Revenue                                23055
# Gross Profit                           23055
# Operating Income                       23055
# Dividends Paid                          9964
# Dividend Yield                          9964
# Cash Ratio                             23055
# Total Assets                           23055
# Total Equity                           23055
# Beta (5Y)                               4982
# Annual Dividend Rate                    9964
# Trailing Twelve Months (TTM) Revenue   23055
# Trailing Twelve Months (TTM) EBITDA    23055
# Trailing Twelve Months (TTM) Earnings  23055

# %%
len(df.columns)
# Out:
# 41

# %%
dd =df.dropna(axis=1, thresh=int(df.shape[0] * 0.5))  # Keep columns with at least 50% data

# %%
df.shape
# Out:
# (23055, 41)

# %%
dd.shape # without code 14 columns were dropped and with code 9 columns were dropped
# Out:
# (23055, 32)

# %%
df.columns
# Out:
# Index(['Company', 'Ticker', 'Date', 'Open', 'High', 'Low', 'Close',
#        'Adj Close', 'Volume', 'Market Cap', 'PE Ratio', 'Beta', 'EPS',
#        'Forward PE', 'Revenue', 'Gross Profit', 'Operating Income',
#        'Net Income', 'Debt to Equity', 'Return on Equity (ROE)',
#        'Current Ratio', 'Dividends Paid', 'Dividend Yield',
#        'Quarterly Revenue Growth', 'Analyst Recommendation', 'Target Price',
#        'Free Cash Flow', 'Operating Margin', 'Profit Margin', 'Cash Ratio',
#        'Quick Ratio', 'Price to Book Ratio', 'Enterprise Value', 'Total Debt',
#        'Total Assets', 'Total Equity', 'Beta (5Y)', 'Annual Dividend Rate',
#        'Trailing Twelve Months (TTM) Revenue',
#        'Trailing Twelve Months (TTM) EBITDA',
#        'Trailing Twelve Months (TTM) Earnings'],
#       dtype='object')

# %%
dd.columns
# Out:
# Index(['Company', 'Ticker', 'Date', 'Open', 'High', 'Low', 'Close',
#        'Adj Close', 'Volume', 'Market Cap', 'PE Ratio', 'EPS', 'Forward PE',
#        'Net Income', 'Debt to Equity', 'Return on Equity (ROE)',
#        'Current Ratio', 'Quarterly Revenue Growth', 'Analyst Recommendation',
#        'Target Price', 'Free Cash Flow', 'Operating Margin', 'Profit Margin',
#        'Quick Ratio', 'Price to Book Ratio', 'Enterprise Value', 'Total Debt'],
#       dtype='object')

# %%
df.isnull().sum()

df = df.dropna(axis=1, thresh=int(df.shape[0]*0.9))  # Drop columns with more than 10% missing values

if 'Revenue' in df.columns:
	df['Revenue'] = df['Revenue'].fillna(df['Revenue'].median())
else:
	print("Column 'Revenue' does not exist in the dataframe.")
# Out:
# Column 'Revenue' does not exist in the dataframe.

# %%
dd[dd['Date'] == '10/17/2024']
# Out:
#         Company Ticker        Date        Open        High         Low  \
# 4981      Apple   AAPL  10/17/2024  233.429993  233.850006  230.520004
# 8106   Facebook   META  10/17/2024  583.330017  584.969971  575.200012
# 13089    Google  GOOGL  10/17/2024  165.729996  166.369995  162.759995
# 18072    Amazon   AMZN  10/17/2024  188.220001  188.940002  186.000000
# 23054   Netflix   NFLX  10/17/2024  704.349976  704.409973  677.880005
#
#             Close   Adj Close    Volume    Market Cap   PE Ratio   Beta  \
# 4981   232.149994  232.149994  32978900  3.580000e+12  35.789955  1.239
# 8106   576.929993  576.929993   8687000  1.470000e+12  29.612986  1.216
# 13089  162.929993  162.929993  21339400  2.020000e+12  23.492826  1.038
# 18072  187.529999  187.529999  24993600  2.000000e+12  45.496414  1.147
# 23054  687.650024  687.650024   8820000  3.250000e+11  42.824500    NaN
#
#          EPS  Forward PE    Net Income  Debt to Equity  \
# ...

# %%
pd.DataFrame(dd[dd.columns[dd.isnull().sum() != 0]].isnull().sum())
pd.DataFrame(dd.loc[dd['Company'] != 'Netflix', dd.columns[dd.isnull().sum() != 0]].isnull().sum()) # Netflix has missing values in Dividends (4982)
pd.DataFrame(dd.loc[dd['Company'] != ('Amazon'), dd.columns[dd.isnull().sum() != 0]].isnull().sum()) # Amazon has missing values in Dividends + Beta (4982)

# Beta	4982
# Dividends Paid	9964
# Dividend Yield	9964
# Beta (5Y)	4982
# Annual Dividend Rate	9964

dd['Company'].value_counts()
# Company
# Apple       4983
# Google      4983
# Amazon      4982
# Netflix     4982
# Facebook    3125
# Name: count, dtype: int64

dd.columns
# Index(['Company', 'Ticker', 'Date', 'Open', 'High', 'Low', 'Close',
#        'Adj Close', 'Volume', 'Market Cap', 'PE Ratio', 'EPS', 'Forward PE',
#        'Net Income', 'Debt to Equity', 'Return on Equity (ROE)',
#        'Current Ratio', 'Quarterly Revenue Growth', 'Analyst Recommendation',
#        'Target Price', 'Free Cash Flow', 'Operating Margin', 'Profit Margin',
#        'Quick Ratio', 'Price to Book Ratio', 'Enterprise Value', 'Total Debt'],
#       dtype='object')
# Out:
#                          0
# Beta                  4982
# Dividends Paid        4982
# Dividend Yield        4982
# Beta (5Y)             4982
# Annual Dividend Rate  4982

# %%
dd['Company'].value_counts()
# Out:
# Company
# Apple       4983
# Google      4983
# Amazon      4982
# Netflix     4982
# Facebook    3125
# Name: count, dtype: int64

# %%
dd[dd['Dividends Paid'].isnull()]
# Out:
#        Company Ticker       Date        Open        High         Low  \
# 13091   Amazon   AMZN 2005-01-03    2.247500    2.272000    2.210500
# 13092   Amazon   AMZN 2005-01-04    2.133500    2.163000    2.075000
# 13093   Amazon   AMZN 2005-01-05    2.078500    2.138000    2.078000
# 13094   Amazon   AMZN 2005-01-06    2.090500    2.112500    2.045000
# 13095   Amazon   AMZN 2005-01-07    2.069000    2.134500    2.058000
# ...        ...    ...        ...         ...         ...         ...
# 23050  Netflix   NFLX 2024-10-11  734.900024  736.000000  721.219971
# 23051  Netflix   NFLX 2024-10-14  725.000000  726.619995  711.309998
# 23052  Netflix   NFLX 2024-10-15  712.510010  713.400024  699.780029
# 23053  Netflix   NFLX 2024-10-16  703.429993  705.590027  697.820007
# 23054  Netflix   NFLX 2024-10-17  704.349976  704.409973  677.880005
#
#             Close   Adj Close     Volume    Market Cap   PE Ratio   Beta  \
# ...
