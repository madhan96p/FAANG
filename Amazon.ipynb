# %%
import pandas as pd
pd.set_option('display.max_columns', None)  # Shows all columns
pd.set_option('display.width', None)  # Shows full width
pd.set_option('display.max_colwidth', None) # Shows full content of the columns

df = pd.read_csv('amazon_data.csv')

# %%
df.value_counts
# Out:
# <bound method DataFrame.value_counts of      Company Ticker        Date        Open        High         Low  \
# 0     Amazon   AMZN    1/3/2005    2.247500    2.272000    2.210500
# 1     Amazon   AMZN    1/4/2005    2.133500    2.163000    2.075000
# 2     Amazon   AMZN    1/5/2005    2.078500    2.138000    2.078000
# 3     Amazon   AMZN    1/6/2005    2.090500    2.112500    2.045000
# 4     Amazon   AMZN    1/7/2005    2.069000    2.134500    2.058000
# ...      ...    ...         ...         ...         ...         ...
# 4977  Amazon   AMZN  10/11/2024  186.630005  189.929993  186.300003
# 4978  Amazon   AMZN  10/14/2024  189.779999  189.830002  187.360001
# 4979  Amazon   AMZN  10/15/2024  187.630005  188.410004  184.580002
# 4980  Amazon   AMZN  10/16/2024  187.050003  187.779999  185.610001
# 4981  Amazon   AMZN  10/17/2024  188.220001  188.940002  186.000000
#
#            Close   Adj Close     Volume    Market Cap   PE Ratio   Beta   EPS  \
# 0       2.226000    2.226000  208930000  2.000000e+12  45.496414  1.147  4.18
# 1       2.107000    2.107000  388370000  2.000000e+12  45.496414  1.147  4.18
# 2       2.088500    2.088500  167084000  2.000000e+12  45.496414  1.147  4.18
# 3       2.052500    2.052500  174018000  2.000000e+12  45.496414  1.147  4.18
# 4       2.116000    2.116000  196732000  2.000000e+12  45.496414  1.147  4.18
# ...          ...         ...        ...           ...        ...    ...   ...
# 4977  188.820007  188.820007   25751600  2.000000e+12  45.496414  1.147  4.18
# 4978  187.539993  187.539993   22614400  2.000000e+12  45.496414  1.147  4.18
# 4979  187.690002  187.690002   32178900  2.000000e+12  45.496414  1.147  4.18
# 4980  186.889999  186.889999   23456800  2.000000e+12  45.496414  1.147  4.18
# 4981  187.529999  187.529999   24993600  2.000000e+12  45.496414  1.147  4.18
#
#       Forward PE  Revenue  Gross Profit  Operating Income    Net Income  \
# 0      32.732357      NaN           NaN               NaN  4.441900e+10
# 1      32.732357      NaN           NaN               NaN  4.441900e+10
# 2      32.732357      NaN           NaN               NaN  4.441900e+10
# 3      32.732357      NaN           NaN               NaN  4.441900e+10
# 4      32.732357      NaN           NaN               NaN  4.441900e+10
# ...          ...      ...           ...               ...           ...
# 4977   32.732357      NaN           NaN               NaN  4.441900e+10
# 4978   32.732357      NaN           NaN               NaN  4.441900e+10
# 4979   32.732357      NaN           NaN               NaN  4.441900e+10
# 4980   32.732357      NaN           NaN               NaN  4.441900e+10
# 4981   32.732357      NaN           NaN               NaN  4.441900e+10
#
#       Debt to Equity  Return on Equity (ROE)  Current Ratio  Dividends Paid  \
# 0             66.756                 0.21933          1.096             NaN
# 1             66.756                 0.21933          1.096             NaN
# 2             66.756                 0.21933          1.096             NaN
# 3             66.756                 0.21933          1.096             NaN
# 4             66.756                 0.21933          1.096             NaN
# ...              ...                     ...            ...             ...
# 4977          66.756                 0.21933          1.096             NaN
# 4978          66.756                 0.21933          1.096             NaN
# 4979          66.756                 0.21933          1.096             NaN
# 4980          66.756                 0.21933          1.096             NaN
# 4981          66.756                 0.21933          1.096             NaN
#
#       Dividend Yield  Quarterly Revenue Growth Analyst Recommendation  \
# 0                NaN                     0.101                    buy
# 1                NaN                     0.101                    buy
# 2                NaN                     0.101                    buy
# 3                NaN                     0.101                    buy
# 4                NaN                     0.101                    buy
# ...              ...                       ...                    ...
# 4977             NaN                     0.101                    buy
# 4978             NaN                     0.101                    buy
# 4979             NaN                     0.101                    buy
# 4980             NaN                     0.101                    buy
# 4981             NaN                     0.101                    buy
#
#       Target Price  Free Cash Flow  Operating Margin  Profit Margin  \
# 0            218.9     59191001088           0.09915         0.0735
# 1            218.9     59191001088           0.09915         0.0735
# 2            218.9     59191001088           0.09915         0.0735
# 3            218.9     59191001088           0.09915         0.0735
# 4            218.9     59191001088           0.09915         0.0735
# ...            ...             ...               ...            ...
# 4977         218.9     59191001088           0.09915         0.0735
# 4978         218.9     59191001088           0.09915         0.0735
# 4979         218.9     59191001088           0.09915         0.0735
# 4980         218.9     59191001088           0.09915         0.0735
# 4981         218.9     59191001088           0.09915         0.0735
#
#       Cash Ratio  Quick Ratio  Price to Book Ratio  Enterprise Value  \
# 0            NaN         0.84             8.437223      2.040000e+12
# 1            NaN         0.84             8.437223      2.040000e+12
# 2            NaN         0.84             8.437223      2.040000e+12
# 3            NaN         0.84             8.437223      2.040000e+12
# 4            NaN         0.84             8.437223      2.040000e+12
# ...          ...          ...                  ...               ...
# 4977         NaN         0.84             8.437223      2.040000e+12
# 4978         NaN         0.84             8.437223      2.040000e+12
# 4979         NaN         0.84             8.437223      2.040000e+12
# 4980         NaN         0.84             8.437223      2.040000e+12
# 4981         NaN         0.84             8.437223      2.040000e+12
#
#         Total Debt  Total Assets  Total Equity  Beta (5Y)  \
# 0     1.580000e+11           NaN           NaN      1.147
# 1     1.580000e+11           NaN           NaN      1.147
# 2     1.580000e+11           NaN           NaN      1.147
# 3     1.580000e+11           NaN           NaN      1.147
# 4     1.580000e+11           NaN           NaN      1.147
# ...            ...           ...           ...        ...
# 4977  1.580000e+11           NaN           NaN      1.147
# 4978  1.580000e+11           NaN           NaN      1.147
# 4979  1.580000e+11           NaN           NaN      1.147
# 4980  1.580000e+11           NaN           NaN      1.147
# 4981  1.580000e+11           NaN           NaN      1.147
#
#       Annual Dividend Rate  Trailing Twelve Months (TTM) Revenue  \
# 0                      NaN                                   NaN
# 1                      NaN                                   NaN
# 2                      NaN                                   NaN
# 3                      NaN                                   NaN
# 4                      NaN                                   NaN
# ...                    ...                                   ...
# 4977                   NaN                                   NaN
# 4978                   NaN                                   NaN
# 4979                   NaN                                   NaN
# 4980                   NaN                                   NaN
# 4981                   NaN                                   NaN
#
#       Trailing Twelve Months (TTM) EBITDA  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 4977                                  NaN
# 4978                                  NaN
# 4979                                  NaN
# 4980                                  NaN
# 4981                                  NaN
#
#       Trailing Twelve Months (TTM) Earnings
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 4977                                    NaN
# 4978                                    NaN
# 4979                                    NaN
# 4980                                    NaN
# 4981                                    NaN
#
# [4982 rows x 41 columns]>

# %%
pd.DataFrame(df[df.columns[df.isnull().sum() != 0]].isnull().sum())
# Out:
#                                           0
# Revenue                                4982
# Gross Profit                           4982
# Operating Income                       4982
# Dividends Paid                         4982
# Dividend Yield                         4982
# Cash Ratio                             4982
# Total Assets                           4982
# Total Equity                           4982
# Annual Dividend Rate                   4982
# Trailing Twelve Months (TTM) Revenue   4982
# Trailing Twelve Months (TTM) EBITDA    4982
# Trailing Twelve Months (TTM) Earnings  4982

# %%
dd =df.dropna(axis=1, thresh=int(df.shape[0] * 0.5))

# %%
dd = dd.drop(columns=['Analyst Recommendation'])

# %%
df.shape # (4982, 41)
# Out:
# (4982, 41)

# %%
dd.shape # 13 columns were dropped
# Out:
# (4982, 28)

# %%
dd['Company'].value_counts()
# Out:
# Company
# Amazon    4982
# Name: count, dtype: int64

# %%
display(dd.head(1))
display(dd.tail(1))
# Out:
#   Company Ticker      Date    Open   High     Low  Close  Adj Close  \
# 0  Amazon   AMZN  1/3/2005  2.2475  2.272  2.2105  2.226      2.226
#
#       Volume    Market Cap   PE Ratio   Beta   EPS  Forward PE    Net Income  \
# 0  208930000  2.000000e+12  45.496414  1.147  4.18   32.732357  4.441900e+10
#
#    Debt to Equity  Return on Equity (ROE)  Current Ratio  \
# 0          66.756                 0.21933          1.096
#
#    Quarterly Revenue Growth  Target Price  Free Cash Flow  Operating Margin  \
# 0                     0.101         218.9     59191001088           0.09915
#
#    Profit Margin  Quick Ratio  Price to Book Ratio  Enterprise Value  \
# 0         0.0735         0.84             8.437223      2.040000e+12
#
#      Total Debt  Beta (5Y)
# 0  1.580000e+11      1.147
#      Company Ticker        Date        Open        High    Low       Close  \
# 4981  Amazon   AMZN  10/17/2024  188.220001  188.940002  186.0  187.529999
#
#        Adj Close    Volume    Market Cap   PE Ratio   Beta   EPS  Forward PE  \
# 4981  187.529999  24993600  2.000000e+12  45.496414  1.147  4.18   32.732357
#
#         Net Income  Debt to Equity  Return on Equity (ROE)  Current Ratio  \
# 4981  4.441900e+10          66.756                 0.21933          1.096
#
#       Quarterly Revenue Growth  Target Price  Free Cash Flow  \
# 4981                     0.101         218.9     59191001088
#
#       Operating Margin  Profit Margin  Quick Ratio  Price to Book Ratio  \
# 4981           0.09915         0.0735         0.84             8.437223
#
#       Enterprise Value    Total Debt  Beta (5Y)
# 4981      2.040000e+12  1.580000e+11      1.147

# %%
dd.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  4982.000000  4982.000000  4982.000000  4982.000000  4982.000000
# mean     52.749220    53.354723    52.087592    52.736332    52.736332
# std      58.915714    59.580503    58.176568    58.883632    58.883632
# min       1.304500     1.315000     1.288000     1.303500     1.303500
# 25%       5.928250     6.017125     5.850000     5.928500     5.928500
# 50%      18.527750    18.685750    18.334499    18.528500    18.528500
# 75%      93.507374    94.556376    92.393002    93.480623    93.480623
# max     200.089996   201.199997   199.050003   200.000000   200.000000
#
#              Volume    Market Cap      PE Ratio          Beta           EPS  \
# count  4.982000e+03  4.982000e+03  4.982000e+03  4.982000e+03  4.982000e+03
# mean   1.056258e+08  2.000000e+12  4.549641e+01  1.147000e+00  4.180000e+00
# std    9.067461e+07  0.000000e+00  7.106141e-15  2.220669e-16  8.882676e-16
# min    1.762600e+07  2.000000e+12  4.549641e+01  1.147000e+00  4.180000e+00
# 25%    5.789350e+07  2.000000e+12  4.549641e+01  1.147000e+00  4.180000e+00
# 50%    8.423600e+07  2.000000e+12  4.549641e+01  1.147000e+00  4.180000e+00
# 75%    1.264360e+08  2.000000e+12  4.549641e+01  1.147000e+00  4.180000e+00
# max    2.086584e+09  2.000000e+12  4.549641e+01  1.147000e+00  4.180000e+00
#
#          Forward PE    Net Income  Debt to Equity  Return on Equity (ROE)  \
# count  4.982000e+03  4.982000e+03    4.982000e+03            4.982000e+03
# mean   3.273236e+01  4.441900e+10    6.675600e+01            2.193300e-01
# std    7.106141e-15  0.000000e+00    2.842456e-14            2.775836e-17
# min    3.273236e+01  4.441900e+10    6.675600e+01            2.193300e-01
# 25%    3.273236e+01  4.441900e+10    6.675600e+01            2.193300e-01
# 50%    3.273236e+01  4.441900e+10    6.675600e+01            2.193300e-01
# 75%    3.273236e+01  4.441900e+10    6.675600e+01            2.193300e-01
# max    3.273236e+01  4.441900e+10    6.675600e+01            2.193300e-01
#
#        Current Ratio  Quarterly Revenue Growth  Target Price  Free Cash Flow  \
# count       4982.000                  4982.000  4.982000e+03    4.982000e+03
# mean           1.096                     0.101  2.189000e+02    5.919100e+10
# std            0.000                     0.000  5.684912e-14    0.000000e+00
# min            1.096                     0.101  2.189000e+02    5.919100e+10
# 25%            1.096                     0.101  2.189000e+02    5.919100e+10
# 50%            1.096                     0.101  2.189000e+02    5.919100e+10
# 75%            1.096                     0.101  2.189000e+02    5.919100e+10
# max            1.096                     0.101  2.189000e+02    5.919100e+10
#
#        Operating Margin  Profit Margin  Quick Ratio  Price to Book Ratio  \
# count      4.982000e+03   4.982000e+03      4982.00         4.982000e+03
# mean       9.915000e-02   7.350000e-02         0.84         8.437223e+00
# std        2.775836e-17   1.387918e-17         0.00         1.776535e-15
# min        9.915000e-02   7.350000e-02         0.84         8.437223e+00
# 25%        9.915000e-02   7.350000e-02         0.84         8.437223e+00
# 50%        9.915000e-02   7.350000e-02         0.84         8.437223e+00
# 75%        9.915000e-02   7.350000e-02         0.84         8.437223e+00
# max        9.915000e-02   7.350000e-02         0.84         8.437223e+00
#
#        Enterprise Value    Total Debt     Beta (5Y)
# count      4.982000e+03  4.982000e+03  4.982000e+03
# mean       2.040000e+12  1.580000e+11  1.147000e+00
# std        0.000000e+00  0.000000e+00  2.220669e-16
# min        2.040000e+12  1.580000e+11  1.147000e+00
# 25%        2.040000e+12  1.580000e+11  1.147000e+00
# 50%        2.040000e+12  1.580000e+11  1.147000e+00
# 75%        2.040000e+12  1.580000e+11  1.147000e+00
# max        2.040000e+12  1.580000e+11  1.147000e+00

# %% [markdown]
# # Standarding

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

Columns = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
dd[Columns] = scaler.fit_transform(dd[Columns])

# %%
dd.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  4.982000e+03  4.982000e+03  4.982000e+03  4.982000e+03  4.982000e+03
# mean   9.127807e-17  9.127807e-17  4.563904e-17  4.563904e-17  4.563904e-17
# std    1.000100e+00  1.000100e+00  1.000100e+00  1.000100e+00  1.000100e+00
# min   -8.732795e-01 -8.735231e-01 -8.732844e-01 -8.735534e-01 -8.735534e-01
# 25%   -7.947908e-01 -7.945947e-01 -7.948601e-01 -7.950007e-01 -7.950007e-01
# 50%   -5.809130e-01 -5.819429e-01 -5.802419e-01 -5.809979e-01 -5.809979e-01
# 75%    6.918739e-01  6.915985e-01  6.928813e-01  6.920154e-01  6.920154e-01
# max    2.501125e+00  2.481686e+00  2.526398e+00  2.501178e+00  2.501178e+00
#
#              Volume    Market Cap      PE Ratio          Beta           EPS  \
# count  4.982000e+03  4.982000e+03  4.982000e+03  4.982000e+03  4.982000e+03
# mean  -2.281952e-17  2.000000e+12  4.549641e+01  1.147000e+00  4.180000e+00
# std    1.000100e+00  0.000000e+00  7.106141e-15  2.220669e-16  8.882676e-16
# min   -9.705986e-01  2.000000e+12  4.549641e+01  1.147000e+00  4.180000e+00
# 25%   -5.264661e-01  2.000000e+12  4.549641e+01  1.147000e+00  4.180000e+00
# 50%   -2.359201e-01  2.000000e+12  4.549641e+01  1.147000e+00  4.180000e+00
# 75%    2.295270e-01  2.000000e+12  4.549641e+01  1.147000e+00  4.180000e+00
# max    2.184908e+01  2.000000e+12  4.549641e+01  1.147000e+00  4.180000e+00
#
#          Forward PE    Net Income  Debt to Equity  Return on Equity (ROE)  \
# count  4.982000e+03  4.982000e+03    4.982000e+03            4.982000e+03
# mean   3.273236e+01  4.441900e+10    6.675600e+01            2.193300e-01
# std    7.106141e-15  0.000000e+00    2.842456e-14            2.775836e-17
# min    3.273236e+01  4.441900e+10    6.675600e+01            2.193300e-01
# 25%    3.273236e+01  4.441900e+10    6.675600e+01            2.193300e-01
# 50%    3.273236e+01  4.441900e+10    6.675600e+01            2.193300e-01
# 75%    3.273236e+01  4.441900e+10    6.675600e+01            2.193300e-01
# max    3.273236e+01  4.441900e+10    6.675600e+01            2.193300e-01
#
#        Current Ratio  Quarterly Revenue Growth  Target Price  Free Cash Flow  \
# count       4982.000                  4982.000  4.982000e+03    4.982000e+03
# mean           1.096                     0.101  2.189000e+02    5.919100e+10
# std            0.000                     0.000  5.684912e-14    0.000000e+00
# min            1.096                     0.101  2.189000e+02    5.919100e+10
# 25%            1.096                     0.101  2.189000e+02    5.919100e+10
# 50%            1.096                     0.101  2.189000e+02    5.919100e+10
# 75%            1.096                     0.101  2.189000e+02    5.919100e+10
# max            1.096                     0.101  2.189000e+02    5.919100e+10
#
#        Operating Margin  Profit Margin  Quick Ratio  Price to Book Ratio  \
# count      4.982000e+03   4.982000e+03      4982.00         4.982000e+03
# mean       9.915000e-02   7.350000e-02         0.84         8.437223e+00
# std        2.775836e-17   1.387918e-17         0.00         1.776535e-15
# min        9.915000e-02   7.350000e-02         0.84         8.437223e+00
# 25%        9.915000e-02   7.350000e-02         0.84         8.437223e+00
# 50%        9.915000e-02   7.350000e-02         0.84         8.437223e+00
# 75%        9.915000e-02   7.350000e-02         0.84         8.437223e+00
# max        9.915000e-02   7.350000e-02         0.84         8.437223e+00
#
#        Enterprise Value    Total Debt     Beta (5Y)
# count      4.982000e+03  4.982000e+03  4.982000e+03
# mean       2.040000e+12  1.580000e+11  1.147000e+00
# std        0.000000e+00  0.000000e+00  2.220669e-16
# min        2.040000e+12  1.580000e+11  1.147000e+00
# 25%        2.040000e+12  1.580000e+11  1.147000e+00
# 50%        2.040000e+12  1.580000e+11  1.147000e+00
# 75%        2.040000e+12  1.580000e+11  1.147000e+00
# max        2.040000e+12  1.580000e+11  1.147000e+00

# %% [markdown]
# # Dedecting outliers
# **Purpose:** Outliers can affect the performance of machine learning models, especially regression models.

# %%
# Dedecting outliers using Z-score
import numpy as np
from scipy import stats

# Z-score method to detect outliers
z_scores = stats.zscore(dd[Columns])
abs_z_scores = np.abs(z_scores)
dd_no_outliers = dd[(abs_z_scores < 3).all(axis=1)]  # Keep rows where Z-score < 3

# %% [markdown]
# ## **Date/Time Features**

# %%
dd['Date'] = pd.to_datetime(dd['Date'])

dd['Year'] = dd['Date'].dt.year
dd['Month'] = dd['Date'].dt.month
dd['Day'] = dd['Date'].dt.day
dd['Weekday'] = dd['Date'].dt.weekday  # 0 = Monday, 6 = Sunday
dd['Is_Weekend'] = dd['Weekday'].isin([5, 6])  # True if Saturday or Sunday
# Just checking for is there any wrong data

# %%
dd['Is_Weekend'].value_counts()
# Out:
# Is_Weekend
# False    4982
# Name: count, dtype: int64

# %%
dd.drop(columns=['Is_Weekend'], inplace=True)

# %% [markdown]
# ## Return Features
# *predicting future stock prices.*

# %%
dd.loc[dd['Date'] == '2005-01-03', 'Prev_Close'] = -0.857272 # First day has no previous close
dd['Return'] = (dd['Close'] - dd['Prev_Close']) / dd['Prev_Close'] * 100
# dd['Prev_Close'] = dd['Close'].shift(1)
# dd.loc[dd['Date'] == '2005-01-03', 'Return'] = 0  # First day has no return -0.857272

# %% [markdown]
# ## Feature Relationships

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select only numeric columns
numeric_cols = dd.select_dtypes(include=[np.number])

# Correlation matrix
correlation_matrix = numeric_cols.corr()

# Plot the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dd.head(15)
# Out:
#    Company Ticker       Date      Open      High       Low     Close  \
# 0   Amazon   AMZN 2005-01-03 -0.857272 -0.857459 -0.857426 -0.857885
# 1   Amazon   AMZN 2005-01-04 -0.859207 -0.859289 -0.859755 -0.859906
# 2   Amazon   AMZN 2005-01-05 -0.860141 -0.859708 -0.859704 -0.860221
# 3   Amazon   AMZN 2005-01-06 -0.859937 -0.860137 -0.860271 -0.860832
# 4   Amazon   AMZN 2005-01-07 -0.860302 -0.859767 -0.860048 -0.859754
# 5   Amazon   AMZN 2005-01-10 -0.859827 -0.859541 -0.859575 -0.860161
# 6   Amazon   AMZN 2005-01-11 -0.860285 -0.860212 -0.860176 -0.860331
# 7   Amazon   AMZN 2005-01-12 -0.860209 -0.859943 -0.860340 -0.859771
# 8   Amazon   AMZN 2005-01-13 -0.859394 -0.858181 -0.859033 -0.859516
# 9   Amazon   AMZN 2005-01-14 -0.859012 -0.858114 -0.859016 -0.857860
# 10  Amazon   AMZN 2005-01-18 -0.857832 -0.857828 -0.857478 -0.857834
# 11  Amazon   AMZN 2005-01-19 -0.857679 -0.858047 -0.858096 -0.858361
# 12  Amazon   AMZN 2005-01-20 -0.860022 -0.858701 -0.859635 -0.859720
# 13  Amazon   AMZN 2005-01-21 -0.859784 -0.859885 -0.860168 -0.860739
# 14  Amazon   AMZN 2005-01-24 -0.860251 -0.860388 -0.860778 -0.861401
#
#     Adj Close    Volume    Market Cap   PE Ratio   Beta   EPS  Forward PE  \
# 0   -0.857885  1.139399  2.000000e+12  45.496414  1.147  4.18   32.732357
# 1   -0.859906  3.118542  2.000000e+12  45.496414  1.147  4.18   32.732357
# 2   -0.860221  0.677856  2.000000e+12  45.496414  1.147  4.18   32.732357
# 3   -0.860832  0.754335  2.000000e+12  45.496414  1.147  4.18   32.732357
# 4   -0.859754  1.004860  2.000000e+12  45.496414  1.147  4.18   32.732357
# 5   -0.860161  0.455875  2.000000e+12  45.496414  1.147  4.18   32.732357
# 6   -0.860331  0.582142  2.000000e+12  45.496414  1.147  4.18   32.732357
# 7   -0.859771  0.615672  2.000000e+12  45.496414  1.147  4.18   32.732357
# 8   -0.859516  2.671867  2.000000e+12  45.496414  1.147  4.18   32.732357
# 9   -0.857860  1.599662  2.000000e+12  45.496414  1.147  4.18   32.732357
# 10  -0.857834  0.408162  2.000000e+12  45.496414  1.147  4.18   32.732357
# 11  -0.858361  0.466640  2.000000e+12  45.496414  1.147  4.18   32.732357
# 12  -0.859720  1.665310  2.000000e+12  45.496414  1.147  4.18   32.732357
# 13  -0.860739  1.173855  2.000000e+12  45.496414  1.147  4.18   32.732357
# 14  -0.861401  0.973823  2.000000e+12  45.496414  1.147  4.18   32.732357
#
#       Net Income  Debt to Equity  Return on Equity (ROE)  Current Ratio  \
# 0   4.441900e+10          66.756                 0.21933          1.096
# 1   4.441900e+10          66.756                 0.21933          1.096
# 2   4.441900e+10          66.756                 0.21933          1.096
# 3   4.441900e+10          66.756                 0.21933          1.096
# 4   4.441900e+10          66.756                 0.21933          1.096
# 5   4.441900e+10          66.756                 0.21933          1.096
# 6   4.441900e+10          66.756                 0.21933          1.096
# 7   4.441900e+10          66.756                 0.21933          1.096
# 8   4.441900e+10          66.756                 0.21933          1.096
# 9   4.441900e+10          66.756                 0.21933          1.096
# 10  4.441900e+10          66.756                 0.21933          1.096
# 11  4.441900e+10          66.756                 0.21933          1.096
# 12  4.441900e+10          66.756                 0.21933          1.096
# 13  4.441900e+10          66.756                 0.21933          1.096
# 14  4.441900e+10          66.756                 0.21933          1.096
#
#     Quarterly Revenue Growth  Target Price  Free Cash Flow  Operating Margin  \
# 0                      0.101         218.9     59191001088           0.09915
# 1                      0.101         218.9     59191001088           0.09915
# 2                      0.101         218.9     59191001088           0.09915
# 3                      0.101         218.9     59191001088           0.09915
# 4                      0.101         218.9     59191001088           0.09915
# 5                      0.101         218.9     59191001088           0.09915
# 6                      0.101         218.9     59191001088           0.09915
# 7                      0.101         218.9     59191001088           0.09915
# 8                      0.101         218.9     59191001088           0.09915
# 9                      0.101         218.9     59191001088           0.09915
# 10                     0.101         218.9     59191001088           0.09915
# 11                     0.101         218.9     59191001088           0.09915
# 12                     0.101         218.9     59191001088           0.09915
# 13                     0.101         218.9     59191001088           0.09915
# 14                     0.101         218.9     59191001088           0.09915
#
#     Profit Margin  Quick Ratio  Price to Book Ratio  Enterprise Value  \
# 0          0.0735         0.84             8.437223      2.040000e+12
# 1          0.0735         0.84             8.437223      2.040000e+12
# 2          0.0735         0.84             8.437223      2.040000e+12
# 3          0.0735         0.84             8.437223      2.040000e+12
# 4          0.0735         0.84             8.437223      2.040000e+12
# 5          0.0735         0.84             8.437223      2.040000e+12
# 6          0.0735         0.84             8.437223      2.040000e+12
# 7          0.0735         0.84             8.437223      2.040000e+12
# 8          0.0735         0.84             8.437223      2.040000e+12
# 9          0.0735         0.84             8.437223      2.040000e+12
# 10         0.0735         0.84             8.437223      2.040000e+12
# 11         0.0735         0.84             8.437223      2.040000e+12
# 12         0.0735         0.84             8.437223      2.040000e+12
# 13         0.0735         0.84             8.437223      2.040000e+12
# 14         0.0735         0.84             8.437223      2.040000e+12
#
#       Total Debt  Beta (5Y)  Year  Month  Day  Weekday  Prev_Close    Return
# 0   1.580000e+11      1.147  2005      1    3        0   -0.857272  0.071539
# 1   1.580000e+11      1.147  2005      1    4        1   -0.857885  0.235595
# 2   1.580000e+11      1.147  2005      1    5        2   -0.859906  0.036540
# 3   1.580000e+11      1.147  2005      1    6        3   -0.860221  0.071079
# 4   1.580000e+11      1.147  2005      1    7        4   -0.860832 -0.125286
# 5   1.580000e+11      1.147  2005      1   10        0   -0.859754  0.047412
# 6   1.580000e+11      1.147  2005      1   11        1   -0.860161  0.019746
# 7   1.580000e+11      1.147  2005      1   12        2   -0.860331 -0.065147
# 8   1.580000e+11      1.147  2005      1   13        3   -0.859771 -0.029632
# 9   1.580000e+11      1.147  2005      1   14        4   -0.859516 -0.192663
# 10  1.580000e+11      1.147  2005      1   18        1   -0.857860 -0.002970
# 11  1.580000e+11      1.147  2005      1   19        2   -0.857834  0.061378
# 12  1.580000e+11      1.147  2005      1   20        3   -0.858361  0.158296
# 13  1.580000e+11      1.147  2005      1   21        4   -0.859720  0.118534
# 14  1.580000e+11      1.147  2005      1   24        0   -0.860739  0.076956
